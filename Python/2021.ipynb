# %%
import numpy as np
import pandas as pd

# %%
df2021= pd.read_csv('2021.csv', sep='\t')
df2021
# Out:
#      World Rank                            Institution         Country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank Education Rank Employability Rank Faculty Rank  \
# ...

# %%
df2021['Year']= 2021
df2021
# Out:
#      World Rank                            Institution         Country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank Education Rank Employability Rank Faculty Rank  \
# ...

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          1000 non-null   int64
#  1   Institution         1000 non-null   object
#  2   Country             1000 non-null   object
#  3   National Rank       1000 non-null   int64
#  4   Education Rank      1000 non-null   object
#  5   Employability Rank  1000 non-null   object
#  6   Faculty Rank        1000 non-null   object
#  7   Research Rank       1000 non-null   object
#  8   Score               1000 non-null   float64
#  9   Year                1000 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 78.2+ KB

# %%
df2021.describe(include='all').T
# Out:
#                      count unique                  top freq    mean  \
# World Rank          1000.0    NaN                  NaN  NaN   500.5
# Institution           1000   1000  American University    1     NaN
# Country               1000     65                  USA  219     NaN
# National Rank       1000.0    NaN                  NaN  NaN  42.969
# Education Rank        1000    361                    -  640     NaN
# Employability Rank    1000    674                    -  327     NaN
# Faculty Rank          1000    246                    -  747     NaN
# Research Rank         1000    980                    -   21     NaN
# Score               1000.0    NaN                  NaN  NaN  75.389
# Year                1000.0    NaN                  NaN  NaN  2021.0
#
#                            std     min     25%     50%     75%     max
# World Rank          288.819436     1.0  250.75   500.5  750.25  1000.0
# Institution                NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
# Define the function to check for '>'
def has_more(value):
    return '>' in str(value)

df2021.applymap(has_more).sum()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_23764\3443946215.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2021.applymap(has_more).sum()
# World Rank            0
# Institution           0
# Country               0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# Year                  0
# dtype: int64

# %%
# Define the function to check for '+'
def has_plus(value):
    return '+' in str(value)

df2021.applymap(has_plus).sum()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_23764\2619206452.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2021.applymap(has_plus).sum()
# World Rank            0
# Institution           0
# Country               0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# Year                  0
# dtype: int64

# %%
# Define the function to check for '-'
def has_dash(value):
    return '-' in str(value)

df2021.applymap(has_dash).sum()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_23764\998274452.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2021.applymap(has_dash).sum()
# World Rank              0
# Institution            29
# Country                 0
# National Rank           0
# Education Rank        640
# Employability Rank    327
# Faculty Rank          747
# Research Rank          21
# Score                   0
# Year                    0
# dtype: int64

# %%
# change - values to Nan
for i in df2021.columns:
    df2021[i] = df2021[i].replace(['-'] , np.nan)     

df2021
# Out:
#      World Rank                            Institution         Country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank Education Rank Employability Rank Faculty Rank  \
# ...

# %%
# Define the function to check for '-'
def has_dash(value):
    return '-' in str(value)

df2021.applymap(has_dash).sum()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_23764\998274452.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2021.applymap(has_dash).sum()
# World Rank             0
# Institution           29
# Country                0
# National Rank          0
# Education Rank         0
# Employability Rank     0
# Faculty Rank           0
# Research Rank          0
# Score                  0
# Year                   0
# dtype: int64

# %%
# convert values of columns to int & float , except columns Institution & Location
for i in df2021.columns:
    if (i == "Institution") or (i == "Country"):
        df2021[i] = df2021[i]
    else:    
        df2021[i] = pd.to_numeric(df2021[i])
df2021
# Out:
#      World Rank                            Institution         Country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank  Education Rank  Employability Rank  Faculty Rank  \
# ...

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          1000 non-null   int64
#  1   Institution         1000 non-null   object
#  2   Country             1000 non-null   object
#  3   National Rank       1000 non-null   int64
#  4   Education Rank      360 non-null    float64
#  5   Employability Rank  673 non-null    float64
#  6   Faculty Rank        253 non-null    float64
#  7   Research Rank       979 non-null    float64
#  8   Score               1000 non-null   float64
#  9   Year                1000 non-null   int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.2+ KB

# %%
df2021.max()
# Out:
# World Rank                         1000
# Institution           Örebro University
# Country                         Uruguay
# National Rank                       219
# Education Rank                    526.0
# Employability Rank               1577.0
# Faculty Rank                      273.0
# Research Rank                    1985.0
# Score                             100.0
# Year                               2021
# dtype: object

# %%
# Replace all nan values to max+1 value of their columns
for i in df2021.columns:
    if (i == "Institution") or (i == "Country"):
        df2021[i] = df2021[i]
    else:    
        df2021[i] = df2021[i].replace(np.nan, df2021[i].max() + 1)

df2021
# Out:
#      World Rank                            Institution         Country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank  Education Rank  Employability Rank  Faculty Rank  \
# ...

# %%
df2021.max()
# Out:
# World Rank                         1000
# Institution           Örebro University
# Country                         Uruguay
# National Rank                       219
# Education Rank                    527.0
# Employability Rank               1578.0
# Faculty Rank                      274.0
# Research Rank                    1986.0
# Score                             100.0
# Year                               2021
# dtype: object

# %%
for i in df2021.columns:
    if i in ["Employability Rank", "Research Rank"]:
        # Apply where condition to specific columns, keeping values <= 1000 or setting to 1001
        df2021[i] = df2021[i].where(df2021[i] <= 1000, 1001)

df2021.max()
# Out:
# World Rank                         1000
# Institution           Örebro University
# Country                         Uruguay
# National Rank                       219
# Education Rank                    527.0
# Employability Rank               1001.0
# Faculty Rank                      274.0
# Research Rank                    1001.0
# Score                             100.0
# Year                               2021
# dtype: object

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          1000 non-null   int64
#  1   Institution         1000 non-null   object
#  2   Country             1000 non-null   object
#  3   National Rank       1000 non-null   int64
#  4   Education Rank      1000 non-null   float64
#  5   Employability Rank  1000 non-null   float64
#  6   Faculty Rank        1000 non-null   float64
#  7   Research Rank       1000 non-null   float64
#  8   Score               1000 non-null   float64
#  9   Year                1000 non-null   int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.2+ KB

# %%
df2021.rename(columns={'Country': 'Location'}, inplace=True)
df2021
# Out:
#      World Rank                            Institution        Location  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                      Hallym University     South Korea
# 996         997                     Marmara University          Turkey
# 997         998             Hangzhou Dianzi University           China
# 998         999                  Alexandria University           Egypt
# 999        1000                    American University             USA
#
#      National Rank  Education Rank  Employability Rank  Faculty Rank  \
# ...

# %%
# Assuming df2021 is your DataFrame
cols = df2021.columns.tolist()  # Convert columns to a list

# Move 'Year' column to be right after 'Location' column
cols.insert(cols.index('Location') + 1, cols.pop(cols.index('Year')))
# Reorder DataFrame with the modified columns list
df2021 = df2021[cols]
df2021
# Out:
#      World Rank                            Institution        Location  Year  \
# 0             1                     Harvard University             USA  2021
# 1             2  Massachusetts Institute of Technology             USA  2021
# 2             3                    Stanford University             USA  2021
# 3             4                University of Cambridge  United Kingdom  2021
# 4             5                   University of Oxford  United Kingdom  2021
# ..          ...                                    ...             ...   ...
# 995         996                      Hallym University     South Korea  2021
# 996         997                     Marmara University          Turkey  2021
# 997         998             Hangzhou Dianzi University           China  2021
# 998         999                  Alexandria University           Egypt  2021
# 999        1000                    American University             USA  2021
#
# ...

# %%
df2021.describe().T
# Out:
#                      count      mean         std     min      25%     50%  \
# World Rank          1000.0   500.500  288.819436     1.0   250.75   500.5
# Year                1000.0  2021.000    0.000000  2021.0  2021.00  2021.0
# National Rank       1000.0    42.969   52.633909     1.0     6.00    21.0
# Education Rank      1000.0   432.190  159.049435     1.0   378.75   527.0
# Employability Rank  1000.0   720.485  349.542701     1.0   419.50  1001.0
# Faculty Rank        1000.0   237.913   73.363312     1.0   270.75   274.0
# Research Rank       1000.0   501.296  290.155332     1.0   250.75   500.5
# Score               1000.0    75.389    4.586159    70.2    71.90    74.1
#
#                         75%     max
# World Rank           750.25  1000.0
# Year                2021.00  2021.0
# National Rank         56.00   219.0
# Education Rank       527.00   527.0
# Employability Rank  1001.00  1001.0
# Faculty Rank         274.00   274.0
# Research Rank        750.25  1001.0
# ...

# %%
df2021.isnull () .sum()
# Out:
# World Rank            0
# Institution           0
# Location              0
# Year                  0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
df2021.to_csv("df2021_f.csv", index=False)
